# %% [markdown]
# # Examine tuning patterns of model hidden units

# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy
import scipy.stats

from spatialnet.trajectory import TrajectoryGenerator
from spatialnet.fileio import load_run, load_params, load_checkpoint
from spatialnet.parameters import print_params
from spatialnet.ratemaps import compute_ratemaps, plot_ratemaps

# %% [markdown]
# ## Load model

# %%
# Directory where model is loaded from
RUN_DIRNAME = '20220524_01'
RUN_DIRPATH = f'models/{RUN_DIRNAME}'

run_params, model = load_run(RUN_DIRPATH)
print_params(run_params)
# Out:
# model:
#   n_units: 100
#   output_bias: false
#   rnn_bias: true
# num_batches: 1000
# num_epochs: 8
# test_batch_size: 500
# trainer:
#   batch_size: 500
#   lambda_h: 10.0
#   lambda_w: 10.0
#   learning_rate: 0.0001
# trajectory:
#   boundary_height: 2.0
#   boundary_shape: square
#   coordinates: cartesian
#   mean_speed: 0.2
#   n_steps: 450
#   rng_seed: 999
#   std_norm: 0.5
#   time_step: 0.1

# %% [markdown]
# ## Ratemaps

# %% [markdown]
# ### Run model on simulation and compute ratemaps

# %%
# Use trajectory generator with different random seed for test data
new_seed = run_params['trajectory']['rng_seed'] + 1
traj_params = dict(run_params['trajectory'], rng_seed=new_seed)
tgen = TrajectoryGenerator(**traj_params)

# Sample test batch
vel, pos = tgen.smp_batch(5000)

# Compute ratemaps
activations, h = compute_ratemaps(model, vel, pos)

# %% [markdown]
# ### Plot ratemaps

# %%
# Plot all cells
n_plot = model.n_units

# Figure size
plt.figure(figsize=(16, 4 * n_plot // 8**2))

# Ratemap plot
rm_fig = plot_ratemaps(activations, n_plot)
plt.imshow(rm_fig)
plt.axis('off')

plt.savefig(f'{RUN_DIRNAME}_tuning.png')

# %% [markdown]
# ###  Activity histogram

# %%
# Threshold above which cell is considered "active"
th = 0.2

# Compute fraction of cells at each time point that are active
h_all = np.reshape(h, (-1, model.n_units))
pct_active = np.count_nonzero(np.abs(h_all) > th, axis=1) / 100

# Plot histogram of activity rates
plt.hist(pct_active, bins=30);
plt.title('Histogram of unit activity across trials')
plt.xlabel(f'fraction of units with u > {th}')
plt.ylabel('num. trials')

plt.savefig(f'{RUN_DIRNAME}_activity.png')

# %% [markdown]
# ## Plot activity

# %%
n_trials_plt = 100
th = 0.2
neuron = 6

fig, ax = plt.subplots(1, figsize=(5, 5))
ax.axis('equal')

for t in range(n_trials_plt):

    x = pos[t, :, 0]
    y = pos[t, :, 1]

    spk_idx = h[t, :, neuron] > th
    x_spk = x[spk_idx]
    y_spk = y[spk_idx]

    plt.plot(x, y, color='grey', alpha=0.2)
    plt.plot(x_spk, y_spk, 'k.')
